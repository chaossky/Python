# %%
import sympy as sp
from IPython.display import display,Math

z=sp.symbols('z')

equation=sp.Eq(z**5,1)
roots=sp.solve(equation, z)

display(Math(r"\boxed{z^5} = 1"))
display(Math(r"\text{The 5 complex roots are :}"))

for i,root in enumerate(roots,1):
    display(Math(
        rf"z_{i} = {sp.latex(root)}"
    ))
# Out:
# $\displaystyle \boxed{z^5} = 1$
# $\displaystyle \text{The 5 complex roots are :}$
# $\displaystyle z_1 = 1$
# $\displaystyle z_2 = - \frac{1}{4} + \frac{\sqrt{5}}{4} - i \sqrt{\frac{\sqrt{5}}{8} + \frac{5}{8}}$
# $\displaystyle z_3 = - \frac{1}{4} + \frac{\sqrt{5}}{4} + i \sqrt{\frac{\sqrt{5}}{8} + \frac{5}{8}}$
# $\displaystyle z_4 = - \frac{\sqrt{5}}{4} - \frac{1}{4} - i \sqrt{\frac{5}{8} - \frac{\sqrt{5}}{8}}$
# $\displaystyle z_5 = - \frac{\sqrt{5}}{4} - \frac{1}{4} + i \sqrt{\frac{5}{8} - \frac{\sqrt{5}}{8}}$
