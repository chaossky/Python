# %%
import yfinance as yf
dat=yf.Ticker("MSFT")

# %%
dat.info
dat.calendar
dat.analyst_price_targets
dat.quarterly_income_stmt
dat.history(period='1mo')
dat.option_chain(dat.options[0]).calls
# Out:
# d:\DevOPS\Python\Tree\.venv\Lib\site-packages\yfinance\scrapers\quote.py:702: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   start = pd.Timestamp.utcnow().floor("D") - datetime.timedelta(days=365 // 2)
# d:\DevOPS\Python\Tree\.venv\Lib\site-packages\yfinance\scrapers\quote.py:704: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   end = pd.Timestamp.utcnow().ceil("D")
# d:\DevOPS\Python\Tree\.venv\Lib\site-packages\yfinance\scrapers\fundamentals.py:120: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   end = pd.Timestamp.utcnow().ceil("D")
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   MSFT260123C00270000 2026-01-21 14:48:44+00:00   270.0     179.60  172.30
# 1   MSFT260123C00280000 2026-01-20 20:42:03+00:00   280.0     174.61  162.25
# 2   MSFT260123C00300000 2026-01-20 20:35:07+00:00   300.0     154.65  142.30
# 3   MSFT260123C00310000 2026-01-20 20:43:23+00:00   310.0     144.68  132.15
# 4   MSFT260123C00320000 2026-01-20 20:43:41+00:00   320.0     134.74  122.20
# ..                  ...                       ...     ...        ...     ...
# 71  MSFT260123C00595000 2026-01-05 20:45:11+00:00   595.0       0.02    0.00
# 72  MSFT260123C00600000 2026-01-16 20:46:02+00:00   600.0       0.01    0.00
# 73  MSFT260123C00605000 2026-01-16 20:47:20+00:00   605.0       0.01     NaN
# 74  MSFT260123C00610000 2025-12-17 18:42:57+00:00   610.0       0.05    0.00
# 75  MSFT260123C00655000 2026-01-21 17:23:54+00:00   655.0       0.04    0.00
#
#        ask    change  percentChange  volume  openInterest  impliedVolatility  \
# 0   175.75 -5.089996      -2.755967     1.0             8           3.868164
# 1   166.15  0.000000       0.000000     4.0            11           2.390629
# 2   146.00  0.000000       0.000000     3.0             6           1.898438
# 3   136.15  0.000000       0.000000     4.0             6           1.750001
# 4   126.15  0.000000       0.000000     5.0             7           1.691408
# ..     ...       ...            ...     ...           ...                ...
# 71    0.02  0.000000       0.000000     7.0             8           1.250004
# 72    0.01  0.000000       0.000000  1012.0          1024           1.218754
# 73    0.01  0.000000       0.000000     NaN           500           1.312503
# 74    0.01  0.000000       0.000000     1.0             1           1.281254
# 75    0.01  0.030000     300.000000     1.0            41           1.531252
#
#     inTheMoney contractSize currency
# 0         True      REGULAR      USD
# 1         True      REGULAR      USD
# 2         True      REGULAR      USD
# 3         True      REGULAR      USD
# 4         True      REGULAR      USD
# ..         ...          ...      ...
# 71       False      REGULAR      USD
# 72       False      REGULAR      USD
# 73       False      REGULAR      USD
# 74       False      REGULAR      USD
# 75       False      REGULAR      USD
#
# [76 rows x 14 columns]
