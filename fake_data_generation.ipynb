# %%
from faker import Faker
fake = Faker()

fake.name()


fake.address()

fake.text()
# Out:
# 'Development special Mr candidate. Much ball tough rich.\nReady sister ever gun. Include risk very price. Soon use science local follow. Music major away economic hour.'

# %%
f_name=fake.name()
print(f_name)
# Out:
# Lindsay Sanchez

# %%
f_addr=fake.address()
print(f_addr)
# Out:
# 5297 Mclaughlin Light
# Biancaville, AK 15310

# %%
fake = Faker('ko_KR')

# %%
f_name=fake.name()
print(f_name)
# Out:
# 이지민

# %%
f_addr=fake.address_detail()
print(f_addr)
# Out:
# 현우김이타운 V동 649호

# %%
print(fake.email())
# Out:
# yeeungim@example.net

# %%
print(fake.sentence())
# Out:
# Esse minus accusamus iste.
