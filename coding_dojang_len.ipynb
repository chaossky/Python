# %%
a=[1,2,3,4,5,6,7,8]
a
len(a)
# Out:
# 8

# %%
b=(1,2,3,4,5,6)
len(b)
# Out:
# 6

# %%
c={1,3,5,7,9}
len(c)
# Out:
# 5

# %%
len(range(0,10,2))
# Out:
# 5

# %%
h="Hello, World"
len(h)
# Out:
# 12

# %%
i="안녕하세요"
len(i)
# Out:
# 5

# %%
len(i.encode('utf-8'))
# Out:
# 15

# %%
j=[34,12,33,23,65,88,43]

# %%
j[0]
# Out:
# 34

# %%
j[1:6]
# Out:
# [12, 33, 23, 65, 88]

# %%
j[0::]
# Out:
# [34, 12, 33, 23, 65, 88, 43]

# %%
j[::2]
# Out:
# [34, 33, 65, 43]

# %%
j[1::2]
# Out:
# [12, 23, 88]

# %%
j[-1]
# Out:
# 43

# %%
j[-2]
# Out:
# 88

# %% [markdown]
# 시퀀스 자료형 중에서 튜플, range, 문자열은 읽기 전용
